# %%
cd Documents/University/Test/
# Out:
# /Users/audreyli/Documents/University/Test

# %%
import pandas as pd
import numpy as np

dataset= pd.read_csv('WORK january_2020.txt', delimiter= "\t", header=None)
dataset.columns= ["Tweet ID", "Date", "Time", "Language", "Country"]

# %%
dataset['Country'].value_counts()
# Out:
# US    104
# GB     16
# PH     14
# CA     12
# AU     12
# MY      9
# CN      8
# NG      7
# ZA      6
# IN      5
# JM      3
# LK      3
# KR      2
# ID      2
# BN      2
# HK      2
# BR      1
# DE      1
# CO      1
# EG      1
# DO      1
# TW      1
# VN      1
# JP      1
# NZ      1
# AE      1
# MM      1
# SG      1
# PL      1
# EC      1
# CZ      1
# TH      1
# CL      1
# ET      1
# PK      1
# PT      1
# IE      1
# CH      1
# CY      1
# BW      1
# FJ      1
# FR      1
# Name: Country, dtype: int64

# %%
country_data= pd.DataFrame([['US', 104], ['GB', 16], ['PH', 14],
                            ['AU', 11], ['CA', 12], ['MY', 9],
                            ['CN', 8], ['NG', 7], ['ZA', 6],
                            ['IN', 5], ['LK', 3], ['JM', 3],
                            ['KR', 2], ['HK', 2], ['ID', 2],
                            ['BN', 2], ['PL', 1], ['BR', 1],
                            ['DE', 1], ['BW', 1], ['CZ', 1],
                            ['CL', 1], ['CO', 1], ['JP', 1],
                            ['EG', 1], ['DO', 1], ['TH', 1],
                            ['ET', 1], ['PT', 1], ['FJ', 1],
                            ['NZ', 1], ['SG', 1], ['AE', 1],
                            ['IE', 1], ['MM', 1], ['EC', 1],
                            ['CH', 1], ['PK', 1], ['VN', 1],
                            ['FR', 1], ['TW', 1], ['CY', 1]],
                          columns=["Country", "Number of Tweets"])

display(country_data)
# Out:
#    Country  Number of Tweets
# 0       US               104
# 1       GB                16
# 2       PH                14
# 3       AU                11
# 4       CA                12
# 5       MY                 9
# 6       CN                 8
# 7       NG                 7
# 8       ZA                 6
# 9       IN                 5
# 10      LK                 3
# 11      JM                 3
# 12      KR                 2
# 13      HK                 2
# 14      ID                 2
# 15      BN                 2
# 16      PL                 1
# 17      BR                 1
# 18      DE                 1
# 19      BW                 1
# 20      CZ                 1
# 21      CL                 1
# 22      CO                 1
# 23      JP                 1
# 24      EG                 1
# 25      DO                 1
# 26      TH                 1
# 27      ET                 1
# 28      PT                 1
# 29      FJ                 1
# 30      NZ                 1
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import timeit

country_graph=sns.displot(data=country_data, x="Country", y="Number of Tweets", height=5, aspect=6, kind="hist")
country_graph.set_axis_labels("Country", "Number of Tweets", size=20)
country_graph.set_xticklabels(size=15)
country_graph.set_yticklabels(size=15)
plt.show()
